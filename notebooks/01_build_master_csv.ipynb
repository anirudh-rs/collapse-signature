# %%
import pandas as pd
import os

# Define all 45 civilisations
civilisations = [
    # Mesopotamia & Middle East
    {
        "civilisation_id": 1, "name": "Sumerian City-States", "region": "Middle East",
        "sub_region": "Mesopotamia", "founded_year": -3000, "peak_year": -2500,
        "collapse_start_year": -2200, "collapse_end_year": -2004,
        "peak_population_m": 0.5, "peak_territory_km2": 30000,
        "latitude": 31.0, "longitude": 46.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "climate",
        "conquered_by": "Akkadian Empire",
        "pressured_by": "", "succeeded_by": "Akkadian Empire",
        "contemporary_rivals": "Akkadian Empire",
        "notes": "Collapsed under Akkadian conquest; drought also implicated"
    },
    {
        "civilisation_id": 2, "name": "Akkadian Empire", "region": "Middle East",
        "sub_region": "Mesopotamia", "founded_year": -2334, "peak_year": -2250,
        "collapse_start_year": -2200, "collapse_end_year": -2154,
        "peak_population_m": 0.8, "peak_territory_km2": 650000,
        "latitude": 33.0, "longitude": 44.0,
        "primary_collapse_trigger": "climate",
        "secondary_collapse_trigger": "fragmentation",
        "conquered_by": "", "pressured_by": "",
        "succeeded_by": "Sumerian Renaissance",
        "contemporary_rivals": "Sumerian City-States",
        "notes": "4.2 kiloyear climate event strongly implicated in collapse"
    },
    {
        "civilisation_id": 3, "name": "Neo-Babylonian Empire", "region": "Middle East",
        "sub_region": "Mesopotamia", "founded_year": -626, "peak_year": -580,
        "collapse_start_year": -560, "collapse_end_year": -539,
        "peak_population_m": 2.0, "peak_territory_km2": 900000,
        "latitude": 32.5, "longitude": 44.5,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "",
        "conquered_by": "Achaemenid Persian Empire",
        "pressured_by": "Achaemenid Persian Empire",
        "succeeded_by": "Achaemenid Persian Empire",
        "contemporary_rivals": "Achaemenid Persian Empire",
        "notes": "Fell to Cyrus the Great of Persia"
    },
    {
        "civilisation_id": 4, "name": "Achaemenid Persian Empire", "region": "Middle East",
        "sub_region": "Persia", "founded_year": -550, "peak_year": -480,
        "collapse_start_year": -334, "collapse_end_year": -330,
        "peak_population_m": 35.0, "peak_territory_km2": 5500000,
        "latitude": 32.0, "longitude": 53.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "",
        "conquered_by": "Macedonian Empire",
        "pressured_by": "Macedonian Empire",
        "succeeded_by": "Seleucid Empire",
        "contemporary_rivals": "Classical Greece|Macedonian Empire",
        "notes": "Conquered by Alexander the Great"
    },
    {
        "civilisation_id": 5, "name": "Sassanid Empire", "region": "Middle East",
        "sub_region": "Persia", "founded_year": 224, "peak_year": 550,
        "collapse_start_year": 633, "collapse_end_year": 651,
        "peak_population_m": 20.0, "peak_territory_km2": 3500000,
        "latitude": 32.0, "longitude": 53.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "pandemic",
        "conquered_by": "Umayyad Caliphate",
        "pressured_by": "Byzantine Empire|Umayyad Caliphate",
        "succeeded_by": "Umayyad Caliphate",
        "contemporary_rivals": "Byzantine Empire",
        "notes": "Weakened by plague and Byzantine wars; fell to Islamic conquest"
    },

    # Mediterranean & Europe - Ancient
    {
        "civilisation_id": 6, "name": "Ancient Egypt - New Kingdom", "region": "Africa",
        "sub_region": "North Africa", "founded_year": -1550, "peak_year": -1279,
        "collapse_start_year": -1150, "collapse_end_year": -1069,
        "peak_population_m": 4.0, "peak_territory_km2": 1000000,
        "latitude": 26.0, "longitude": 30.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "climate",
        "conquered_by": "",
        "pressured_by": "Sea Peoples",
        "succeeded_by": "",
        "contemporary_rivals": "Hittite Empire",
        "notes": "Bronze Age Collapse; Sea Peoples invasions and internal fragmentation"
    },
    {
        "civilisation_id": 7, "name": "Classical Greece", "region": "Europe",
        "sub_region": "Mediterranean", "founded_year": -800, "peak_year": -450,
        "collapse_start_year": -350, "collapse_end_year": -146,
        "peak_population_m": 8.0, "peak_territory_km2": 250000,
        "latitude": 39.0, "longitude": 22.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "fragmentation",
        "conquered_by": "Roman Empire",
        "pressured_by": "Macedonian Empire|Roman Empire",
        "succeeded_by": "Macedonian Empire",
        "contemporary_rivals": "Achaemenid Persian Empire|Macedonian Empire",
        "notes": "Absorbed by Macedon then Rome; internal city-state rivalry weakened cohesion"
    },
    {
        "civilisation_id": 8, "name": "Macedonian Empire", "region": "Europe",
        "sub_region": "Mediterranean", "founded_year": -336, "peak_year": -323,
        "collapse_start_year": -323, "collapse_end_year": -301,
        "peak_population_m": 50.0, "peak_territory_km2": 5200000,
        "latitude": 41.0, "longitude": 41.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "Seleucid Empire",
        "contemporary_rivals": "Achaemenid Persian Empire",
        "notes": "Fragmented immediately on Alexander's death into Diadochi kingdoms"
    },
    {
        "civilisation_id": 9, "name": "Roman Empire", "region": "Europe",
        "sub_region": "Mediterranean", "founded_year": -27, "peak_year": 117,
        "collapse_start_year": 376, "collapse_end_year": 476,
        "peak_population_m": 70.0, "peak_territory_km2": 5000000,
        "latitude": 42.0, "longitude": 12.0,
        "primary_collapse_trigger": "overextension",
        "secondary_collapse_trigger": "migration",
        "conquered_by": "",
        "pressured_by": "Sassanid Empire",
        "succeeded_by": "Byzantine Empire|Holy Roman Empire",
        "contemporary_rivals": "Parthian Empire|Sassanid Empire|Han Dynasty",
        "notes": "Western Rome fell 476 CE; overextension, migration pressure, economic collapse"
    },
    {
        "civilisation_id": 10, "name": "Byzantine Empire", "region": "Europe",
        "sub_region": "Mediterranean", "founded_year": 330, "peak_year": 555,
        "collapse_start_year": 1204, "collapse_end_year": 1453,
        "peak_population_m": 30.0, "peak_territory_km2": 3500000,
        "latitude": 41.0, "longitude": 29.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "overextension",
        "conquered_by": "Ottoman Empire",
        "pressured_by": "Ottoman Empire|Seljuk Turks",
        "succeeded_by": "Ottoman Empire",
        "contemporary_rivals": "Sassanid Empire|Umayyad Caliphate|Ottoman Empire",
        "notes": "Gradual erosion over centuries; final conquest by Ottomans 1453"
    },

    # Islamic World
    {
        "civilisation_id": 11, "name": "Parthian Empire", "region": "Middle East",
        "sub_region": "Persia", "founded_year": -247, "peak_year": -50,
        "collapse_start_year": 210, "collapse_end_year": 224,
        "peak_population_m": 12.0, "peak_territory_km2": 2500000,
        "latitude": 32.0, "longitude": 53.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "fragmentation",
        "conquered_by": "Sassanid Empire",
        "pressured_by": "Roman Empire|Sassanid Empire",
        "succeeded_by": "Sassanid Empire",
        "contemporary_rivals": "Roman Empire",
        "notes": "Rome's great eastern rival; fell to internal Sassanid rebellion"
    },
    {
        "civilisation_id": 12, "name": "Umayyad Caliphate", "region": "Middle East",
        "sub_region": "Arabia", "founded_year": 661, "peak_year": 720,
        "collapse_start_year": 740, "collapse_end_year": 750,
        "peak_population_m": 33.0, "peak_territory_km2": 11100000,
        "latitude": 33.5, "longitude": 36.3,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "conquest",
        "conquered_by": "Abbasid Caliphate",
        "pressured_by": "Abbasid Caliphate",
        "succeeded_by": "Abbasid Caliphate",
        "contemporary_rivals": "Byzantine Empire|Tang Dynasty",
        "notes": "Overthrown by Abbasid Revolution; internal ethnic tensions"
    },
    {
        "civilisation_id": 13, "name": "Abbasid Caliphate", "region": "Middle East",
        "sub_region": "Arabia", "founded_year": 750, "peak_year": 850,
        "collapse_start_year": 1200, "collapse_end_year": 1258,
        "peak_population_m": 30.0, "peak_territory_km2": 4300000,
        "latitude": 33.3, "longitude": 44.4,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "fragmentation",
        "conquered_by": "Mongol Empire",
        "pressured_by": "Mongol Empire|Crusaders",
        "succeeded_by": "Mongol Empire|Mamluk Sultanate",
        "contemporary_rivals": "Byzantine Empire|Mongol Empire",
        "notes": "Sacked by Mongols 1258; Baghdad destroyed"
    },
    {
        "civilisation_id": 14, "name": "Ottoman Empire", "region": "Middle East",
        "sub_region": "Anatolia", "founded_year": 1299, "peak_year": 1683,
        "collapse_start_year": 1908, "collapse_end_year": 1922,
        "peak_population_m": 32.0, "peak_territory_km2": 5200000,
        "latitude": 39.0, "longitude": 35.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "overextension",
        "conquered_by": "",
        "pressured_by": "British Empire|Russian Empire",
        "succeeded_by": "Republic of Turkey",
        "contemporary_rivals": "Byzantine Empire|Safavid Persia|British Empire|Russian Empire",
        "notes": "Sick Man of Europe; WWI defeat triggered final collapse"
    },

    # South Asia
    {
        "civilisation_id": 15, "name": "Maurya Empire", "region": "South Asia",
        "sub_region": "Indian Subcontinent", "founded_year": -322, "peak_year": -250,
        "collapse_start_year": -210, "collapse_end_year": -185,
        "peak_population_m": 50.0, "peak_territory_km2": 5000000,
        "latitude": 25.0, "longitude": 80.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "Gupta Empire",
        "contemporary_rivals": "Seleucid Empire",
        "notes": "Fragmented after Ashoka; succession crises"
    },
    {
        "civilisation_id": 16, "name": "Gupta Empire", "region": "South Asia",
        "sub_region": "Indian Subcontinent", "founded_year": 320, "peak_year": 400,
        "collapse_start_year": 480, "collapse_end_year": 550,
        "peak_population_m": 35.0, "peak_territory_km2": 3500000,
        "latitude": 25.0, "longitude": 80.0,
        "primary_collapse_trigger": "migration",
        "secondary_collapse_trigger": "fragmentation",
        "conquered_by": "",
        "pressured_by": "Huna invaders",
        "succeeded_by": "",
        "contemporary_rivals": "Sassanid Empire",
        "notes": "Huna invasions triggered fragmentation"
    },
    {
        "civilisation_id": 17, "name": "Mughal Empire", "region": "South Asia",
        "sub_region": "Indian Subcontinent", "founded_year": 1526, "peak_year": 1700,
        "collapse_start_year": 1707, "collapse_end_year": 1857,
        "peak_population_m": 150.0, "peak_territory_km2": 4000000,
        "latitude": 25.0, "longitude": 80.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "conquest",
        "conquered_by": "British Empire",
        "pressured_by": "British Empire|Maratha Empire",
        "succeeded_by": "British Empire",
        "contemporary_rivals": "Safavid Persia|British Empire",
        "notes": "Long fragmentation post-Aurangzeb; British absorbed remnants 1857"
    },

    # East Asia
    {
        "civilisation_id": 18, "name": "Qin Dynasty", "region": "East Asia",
        "sub_region": "China", "founded_year": -221, "peak_year": -215,
        "collapse_start_year": -210, "collapse_end_year": -206,
        "peak_population_m": 40.0, "peak_territory_km2": 3400000,
        "latitude": 34.0, "longitude": 109.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "Han Dynasty",
        "contemporary_rivals": "Maurya Empire",
        "notes": "Collapsed under peasant revolts after Qin Shi Huang's death"
    },
    {
        "civilisation_id": 19, "name": "Han Dynasty", "region": "East Asia",
        "sub_region": "China", "founded_year": -206, "peak_year": 100,
        "collapse_start_year": 184, "collapse_end_year": 220,
        "peak_population_m": 60.0, "peak_territory_km2": 6500000,
        "latitude": 34.0, "longitude": 109.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "Xiongnu",
        "succeeded_by": "Tang Dynasty",
        "contemporary_rivals": "Roman Empire|Parthian Empire",
        "notes": "Yellow Turban Rebellion; warlordism; Three Kingdoms period"
    },
    {
        "civilisation_id": 20, "name": "Tang Dynasty", "region": "East Asia",
        "sub_region": "China", "founded_year": 618, "peak_year": 750,
        "collapse_start_year": 875, "collapse_end_year": 907,
        "peak_population_m": 80.0, "peak_territory_km2": 5400000,
        "latitude": 34.0, "longitude": 109.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "Song Dynasty",
        "contemporary_rivals": "Abbasid Caliphate|Byzantine Empire",
        "notes": "An Lushan Rebellion weakened Tang; Huang Chao Rebellion finished it"
    },
    {
        "civilisation_id": 21, "name": "Song Dynasty", "region": "East Asia",
        "sub_region": "China", "founded_year": 960, "peak_year": 1100,
        "collapse_start_year": 1234, "collapse_end_year": 1279,
        "peak_population_m": 100.0, "peak_territory_km2": 3100000,
        "latitude": 34.0, "longitude": 109.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "",
        "conquered_by": "Mongol Empire",
        "pressured_by": "Mongol Empire|Jurchen Jin",
        "succeeded_by": "Yuan Dynasty",
        "contemporary_rivals": "Mongol Empire",
        "notes": "Conquered by Kublai Khan's Mongols"
    },
    {
        "civilisation_id": 22, "name": "Yuan Dynasty", "region": "East Asia",
        "sub_region": "China", "founded_year": 1271, "peak_year": 1310,
        "collapse_start_year": 1340, "collapse_end_year": 1368,
        "peak_population_m": 75.0, "peak_territory_km2": 4000000,
        "latitude": 40.0, "longitude": 116.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "pandemic",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "Ming Dynasty",
        "contemporary_rivals": "Ming Dynasty",
        "notes": "Black Death devastated population; Red Turban Rebellion overthrew Mongol rule"
    },
    {
        "civilisation_id": 23, "name": "Ming Dynasty", "region": "East Asia",
        "sub_region": "China", "founded_year": 1368, "peak_year": 1450,
        "collapse_start_year": 1620, "collapse_end_year": 1644,
        "peak_population_m": 200.0, "peak_territory_km2": 6500000,
        "latitude": 34.0, "longitude": 109.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "climate",
        "conquered_by": "Qing Dynasty",
        "pressured_by": "Qing Dynasty",
        "succeeded_by": "Qing Dynasty",
        "contemporary_rivals": "Qing Dynasty|Ottoman Empire",
        "notes": "Little Ice Age famines; peasant rebellions; Manchu conquest"
    },
    {
        "civilisation_id": 24, "name": "Qing Dynasty", "region": "East Asia",
        "sub_region": "China", "founded_year": 1644, "peak_year": 1800,
        "collapse_start_year": 1850, "collapse_end_year": 1912,
        "peak_population_m": 430.0, "peak_territory_km2": 13000000,
        "latitude": 35.0, "longitude": 105.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "overextension",
        "conquered_by": "",
        "pressured_by": "British Empire|Japanese Empire",
        "succeeded_by": "Republic of China",
        "contemporary_rivals": "British Empire|Russian Empire|Japanese Empire",
        "notes": "Opium Wars, Taiping Rebellion, Boxer Rebellion; abdication 1912"
    },

    # Central Asia / Steppe
    {
        "civilisation_id": 25, "name": "Mongol Empire", "region": "Central Asia",
        "sub_region": "Steppe", "founded_year": 1206, "peak_year": 1260,
        "collapse_start_year": 1260, "collapse_end_year": 1368,
        "peak_population_m": 100.0, "peak_territory_km2": 24000000,
        "latitude": 47.0, "longitude": 107.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "pandemic",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "Yuan Dynasty|Golden Horde|Ilkhanate|Timurid Empire",
        "contemporary_rivals": "Abbasid Caliphate|Song Dynasty",
        "notes": "Largest contiguous empire; fragmented into khanates after 1259"
    },
    {
        "civilisation_id": 26, "name": "Timurid Empire", "region": "Central Asia",
        "sub_region": "Steppe", "founded_year": 1370, "peak_year": 1405,
        "collapse_start_year": 1460, "collapse_end_year": 1507,
        "peak_population_m": 8.0, "peak_territory_km2": 4400000,
        "latitude": 39.0, "longitude": 63.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "conquest",
        "conquered_by": "Uzbek Khanate",
        "pressured_by": "Uzbek Khanate|Ottoman Empire",
        "succeeded_by": "Mughal Empire",
        "contemporary_rivals": "Ottoman Empire|Ming Dynasty",
        "notes": "Tamerlane's empire; fragmented after his death; Babur fled to found Mughals"
    },

    # Sub-Saharan Africa
    {
        "civilisation_id": 27, "name": "Kingdom of Kush", "region": "Africa",
        "sub_region": "Sub-Saharan Africa", "founded_year": -1070, "peak_year": -700,
        "collapse_start_year": 300, "collapse_end_year": 350,
        "peak_population_m": 1.0, "peak_territory_km2": 600000,
        "latitude": 15.0, "longitude": 32.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "climate",
        "conquered_by": "Kingdom of Aksum",
        "pressured_by": "Kingdom of Aksum|Roman Egypt",
        "succeeded_by": "Kingdom of Aksum",
        "contemporary_rivals": "Roman Empire|Kingdom of Aksum",
        "notes": "Conquered by Aksum; desertification also weakened agricultural base"
    },
    {
        "civilisation_id": 28, "name": "Kingdom of Aksum", "region": "Africa",
        "sub_region": "Sub-Saharan Africa", "founded_year": 100, "peak_year": 350,
        "collapse_start_year": 700, "collapse_end_year": 940,
        "peak_population_m": 3.0, "peak_territory_km2": 1250000,
        "latitude": 14.0, "longitude": 38.0,
        "primary_collapse_trigger": "economic",
        "secondary_collapse_trigger": "climate",
        "conquered_by": "",
        "pressured_by": "Umayyad Caliphate",
        "succeeded_by": "",
        "contemporary_rivals": "Byzantine Empire|Sassanid Empire|Umayyad Caliphate",
        "notes": "Islamic expansion cut Red Sea trade routes; climate shifts weakened agriculture"
    },
    {
        "civilisation_id": 29, "name": "Mali Empire", "region": "Africa",
        "sub_region": "Sub-Saharan Africa", "founded_year": 1235, "peak_year": 1350,
        "collapse_start_year": 1400, "collapse_end_year": 1670,
        "peak_population_m": 20.0, "peak_territory_km2": 1240000,
        "latitude": 12.0, "longitude": -8.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "Songhai Empire",
        "succeeded_by": "Songhai Empire",
        "contemporary_rivals": "Mongol Empire|Ottoman Empire",
        "notes": "Fragmented as Songhai rose; succession disputes weakened central authority"
    },

    # Americas
    {
        "civilisation_id": 30, "name": "Classic Maya", "region": "Americas",
        "sub_region": "Mesoamerica", "founded_year": 250, "peak_year": 750,
        "collapse_start_year": 800, "collapse_end_year": 900,
        "peak_population_m": 10.0, "peak_territory_km2": 300000,
        "latitude": 17.0, "longitude": -89.0,
        "primary_collapse_trigger": "climate",
        "secondary_collapse_trigger": "fragmentation",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "",
        "contemporary_rivals": "Teotihuacan",
        "notes": "Severe drought cycles; internal warfare; agricultural collapse"
    },
    {
        "civilisation_id": 31, "name": "Teotihuacan", "region": "Americas",
        "sub_region": "Mesoamerica", "founded_year": -100, "peak_year": 400,
        "collapse_start_year": 650, "collapse_end_year": 750,
        "peak_population_m": 0.5, "peak_territory_km2": 26000,
        "latitude": 19.7, "longitude": -98.8,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "climate",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "Aztec Empire",
        "contemporary_rivals": "Classic Maya",
        "notes": "Evidence of internal burning and destruction; drought likely contributing factor"
    },
    {
        "civilisation_id": 32, "name": "Aztec Empire", "region": "Americas",
        "sub_region": "Mesoamerica", "founded_year": 1345, "peak_year": 1500,
        "collapse_start_year": 1519, "collapse_end_year": 1521,
        "peak_population_m": 6.0, "peak_territory_km2": 220000,
        "latitude": 19.4, "longitude": -99.1,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "pandemic",
        "conquered_by": "Spanish Empire",
        "pressured_by": "Spanish Empire",
        "succeeded_by": "Spanish Empire",
        "contemporary_rivals": "Inca Empire",
        "notes": "Spanish conquest aided by smallpox epidemic and local alliances"
    },
    {
        "civilisation_id": 33, "name": "Inca Empire", "region": "Americas",
        "sub_region": "South America", "founded_year": 1438, "peak_year": 1527,
        "collapse_start_year": 1532, "collapse_end_year": 1533,
        "peak_population_m": 12.0, "peak_territory_km2": 2000000,
        "latitude": -13.0, "longitude": -72.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "pandemic",
        "conquered_by": "Spanish Empire",
        "pressured_by": "Spanish Empire",
        "succeeded_by": "Spanish Empire",
        "contemporary_rivals": "Aztec Empire",
        "notes": "Smallpox preceded Spanish arrival; civil war weakened resistance"
    },

    # European Colonial & Modern
    {
        "civilisation_id": 34, "name": "Carolingian Empire", "region": "Europe",
        "sub_region": "Western Europe", "founded_year": 800, "peak_year": 814,
        "collapse_start_year": 840, "collapse_end_year": 888,
        "peak_population_m": 15.0, "peak_territory_km2": 1112000,
        "latitude": 49.0, "longitude": 8.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "",
        "conquered_by": "",
        "pressured_by": "Viking raids",
        "succeeded_by": "Holy Roman Empire",
        "contemporary_rivals": "Byzantine Empire|Abbasid Caliphate",
        "notes": "Treaty of Verdun 843 split empire; Viking pressure accelerated fragmentation"
    },
    {
        "civilisation_id": 35, "name": "Holy Roman Empire", "region": "Europe",
        "sub_region": "Western Europe", "founded_year": 962, "peak_year": 1200,
        "collapse_start_year": 1618, "collapse_end_year": 1806,
        "peak_population_m": 20.0, "peak_territory_km2": 600000,
        "latitude": 51.0, "longitude": 10.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "overextension",
        "conquered_by": "",
        "pressured_by": "French Empire|Napoleon",
        "succeeded_by": "German Empire",
        "contemporary_rivals": "Ottoman Empire|French Colonial Empire",
        "notes": "30 Years War devastated it; Napoleon dissolved it formally 1806"
    },
    {
        "civilisation_id": 36, "name": "Spanish Empire", "region": "Europe",
        "sub_region": "Western Europe", "founded_year": 1492, "peak_year": 1650,
        "collapse_start_year": 1808, "collapse_end_year": 1898,
        "peak_population_m": 68.0, "peak_territory_km2": 20000000,
        "latitude": 40.0, "longitude": -4.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "British Empire|Napoleon",
        "succeeded_by": "",
        "contemporary_rivals": "British Empire|French Colonial Empire|Ottoman Empire",
        "notes": "Napoleonic invasion triggered Latin American independence movements"
    },
    {
        "civilisation_id": 37, "name": "Napoleonic Empire", "region": "Europe",
        "sub_region": "Western Europe", "founded_year": 1804, "peak_year": 1812,
        "collapse_start_year": 1812, "collapse_end_year": 1815,
        "peak_population_m": 44.0, "peak_territory_km2": 2100000,
        "latitude": 46.0, "longitude": 2.0,
        "primary_collapse_trigger": "overextension",
        "secondary_collapse_trigger": "climate",
        "conquered_by": "",
        "pressured_by": "Russian Empire|British Empire",
        "succeeded_by": "",
        "contemporary_rivals": "British Empire|Russian Empire|Austrian Empire",
        "notes": "Russian campaign overextension; 1815 Waterloo; volcanic winter 1815 (Tambora)"
    },
    {
        "civilisation_id": 38, "name": "Austro-Hungarian Empire", "region": "Europe",
        "sub_region": "Central Europe", "founded_year": 1867, "peak_year": 1900,
        "collapse_start_year": 1914, "collapse_end_year": 1918,
        "peak_population_m": 52.0, "peak_territory_km2": 676000,
        "latitude": 47.0, "longitude": 14.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "overextension",
        "conquered_by": "",
        "pressured_by": "Russian Empire|German Empire",
        "succeeded_by": "Austria|Hungary|Czechoslovakia|Yugoslavia",
        "contemporary_rivals": "Russian Empire|Ottoman Empire|German Empire",
        "notes": "WWI defeat; multinational empire fragmented into nation-states"
    },
    {
        "civilisation_id": 39, "name": "German Empire and Third Reich", "region": "Europe",
        "sub_region": "Central Europe", "founded_year": 1871, "peak_year": 1942,
        "collapse_start_year": 1943, "collapse_end_year": 1945,
        "peak_population_m": 90.0, "peak_territory_km2": 3600000,
        "latitude": 51.0, "longitude": 10.0,
        "primary_collapse_trigger": "overextension",
        "secondary_collapse_trigger": "conquest",
        "conquered_by": "Allied Powers",
        "pressured_by": "British Empire|Russian Empire|USA",
        "succeeded_by": "West Germany|East Germany",
        "contemporary_rivals": "British Empire|Russian Empire|USA",
        "notes": "Two-front overextension; unconditional surrender 1945"
    },
    {
        "civilisation_id": 40, "name": "Italian Colonial Empire", "region": "Europe",
        "sub_region": "Mediterranean", "founded_year": 1882, "peak_year": 1936,
        "collapse_start_year": 1940, "collapse_end_year": 1947,
        "peak_population_m": 44.0, "peak_territory_km2": 3798000,
        "latitude": 42.0, "longitude": 12.0,
        "primary_collapse_trigger": "conquest",
        "secondary_collapse_trigger": "overextension",
        "conquered_by": "Allied Powers",
        "pressured_by": "British Empire|Allied Powers",
        "succeeded_by": "",
        "contemporary_rivals": "British Empire|German Empire|French Colonial Empire",
        "notes": "WWII defeats in Africa and Europe; Allied invasion of Italy 1943"
    },
    {
        "civilisation_id": 41, "name": "Empire of Japan", "region": "East Asia",
        "sub_region": "East Asia", "founded_year": 1868, "peak_year": 1942,
        "collapse_start_year": 1944, "collapse_end_year": 1947,
        "peak_population_m": 97.0, "peak_territory_km2": 7400000,
        "latitude": 36.0, "longitude": 138.0,
        "primary_collapse_trigger": "overextension",
        "secondary_collapse_trigger": "conquest",
        "conquered_by": "Allied Powers",
        "pressured_by": "USA|British Empire|USSR",
        "succeeded_by": "Japan",
        "contemporary_rivals": "USA|British Empire|Chinese Republic",
        "notes": "Pacific overextension; atomic bombs; unconditional surrender 1945"
    },
    {
        "civilisation_id": 42, "name": "French Colonial Empire", "region": "Europe",
        "sub_region": "Western Europe", "founded_year": 1534, "peak_year": 1920,
        "collapse_start_year": 1954, "collapse_end_year": 1980,
        "peak_population_m": 110.0, "peak_territory_km2": 13500000,
        "latitude": 46.0, "longitude": 2.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "overextension",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "",
        "contemporary_rivals": "British Empire|German Empire",
        "notes": "Indochina War then Algeria triggered decolonisation wave"
    },
    {
        "civilisation_id": 43, "name": "British Empire", "region": "Europe",
        "sub_region": "Western Europe", "founded_year": 1583, "peak_year": 1920,
        "collapse_start_year": 1947, "collapse_end_year": 1997,
        "peak_population_m": 458.0, "peak_territory_km2": 35500000,
        "latitude": 51.5, "longitude": -0.1,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "Commonwealth of Nations",
        "contemporary_rivals": "French Colonial Empire|Russian Empire|German Empire",
        "notes": "WWII economic exhaustion; Indian independence 1947 triggered decolonisation"
    },
    {
        "civilisation_id": 44, "name": "Russian Empire and USSR", "region": "Europe",
        "sub_region": "Eastern Europe", "founded_year": 1547, "peak_year": 1945,
        "collapse_start_year": 1989, "collapse_end_year": 1991,
        "peak_population_m": 293.0, "peak_territory_km2": 22400000,
        "latitude": 55.0, "longitude": 37.0,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "USA",
        "succeeded_by": "Russia|Ukraine|15 successor states",
        "contemporary_rivals": "British Empire|USA|German Empire",
        "notes": "Cold War economic exhaustion; Gorbachev reforms triggered rapid dissolution"
    },
    {
        "civilisation_id": 45, "name": "Portuguese Empire", "region": "Europe",
        "sub_region": "Western Europe", "founded_year": 1415, "peak_year": 1550,
        "collapse_start_year": 1974, "collapse_end_year": 1999,
        "peak_population_m": 50.0, "peak_territory_km2": 10400000,
        "latitude": 38.7, "longitude": -9.1,
        "primary_collapse_trigger": "fragmentation",
        "secondary_collapse_trigger": "economic",
        "conquered_by": "",
        "pressured_by": "",
        "succeeded_by": "",
        "contemporary_rivals": "Spanish Empire|British Empire|French Colonial Empire",
        "notes": "Carnation Revolution 1974 triggered rapid decolonisation; Macau handover 1999"
    },
]

# Build dataframe
df = pd.DataFrame(civilisations)

# Calculate collapse duration
df["collapse_duration_years"] = df["collapse_end_year"] - df["collapse_start_year"]

# Calculate total lifespan
df["lifespan_years"] = df["collapse_end_year"] - df["founded_year"]

# Save
os.makedirs("../data/raw", exist_ok=True)
df.to_csv("../data/raw/civilisations_master.csv", index=False)

print(f"Master CSV saved: {len(df)} civilisations")
print(f"\nCollapse duration range: {df['collapse_duration_years'].min()} to {df['collapse_duration_years'].max()} years")
print(f"Lifespan range: {df['lifespan_years'].min()} to {df['lifespan_years'].max()} years")
print(f"\nCollapse triggers breakdown:")
print(df['primary_collapse_trigger'].value_counts())
print(f"\nRegions breakdown:")
print(df['region'].value_counts())
# Out:
# Master CSV saved: 45 civilisations
#
# Collapse duration range: 1 to 270 years
# Lifespan range: 11 to 1420 years
#
# Collapse triggers breakdown:
# primary_collapse_trigger
# fragmentation    24
# conquest         13
# overextension     4
# climate           2
# migration         1
# economic          1
# Name: count, dtype: int64
#
# Regions breakdown:
# region
# Europe          15
# Middle East      9
# East Asia        8
# Africa           4
# Americas         4
# South Asia       3
# Central Asia     2
# Name: count, dtype: int64

# %%
import requests
import os

# Maddison Project 2023 - direct download
url = "https://dataverse.nl/api/access/datafile/421302"
output_path = "../data/raw/maddison_gdp.xlsx"

print("Downloading Maddison Project data...")
response = requests.get(url, timeout=60)

if response.status_code == 200:
    with open(output_path, "wb") as f:
        f.write(response.content)
    print(f"Downloaded successfully: {output_path}")
    print(f"File size: {os.path.getsize(output_path) / 1024:.1f} KB")
else:
    print(f"Download failed: HTTP {response.status_code}")
    print("Manual download instructions will follow")
# Out:
# ...
# Downloaded successfully: ../data/raw/maddison_gdp.xlsx
# File size: 4788.9 KB

# %%
import pandas as pd
import os

stressor_events = [
    # Climate Events
    {
        "event_id": 1,
        "event_name": "4.2 Kiloyear Event",
        "event_type": "climate",
        "start_year": -2200,
        "end_year": -2100,
        "severity": "severe",
        "geographic_scope": "global",
        "affected_regions": "Middle East|South Asia|East Asia|North Africa",
        "description": "Prolonged aridification event. Implicated in collapse of Akkadian Empire, Old Kingdom Egypt, Indus Valley civilisation",
        "source": "Weiss et al. 1993; deMenocal 2001"
    },
    {
        "event_id": 2,
        "event_name": "Late Bronze Age Drought",
        "event_type": "climate",
        "start_year": -1200,
        "end_year": -1150,
        "severity": "severe",
        "geographic_scope": "regional",
        "affected_regions": "Middle East|Mediterranean|North Africa",
        "description": "Multi-decade drought contributing to Bronze Age Collapse. Pollen and isotope evidence from Cyprus and Syria",
        "source": "Brandon Drake 2012; Kaniewski et al. 2013"
    },
    {
        "event_id": 3,
        "event_name": "Roman Climate Optimum",
        "event_type": "climate",
        "start_year": -200,
        "end_year": 150,
        "severity": "beneficial",
        "geographic_scope": "regional",
        "affected_regions": "Europe|Middle East|North Africa",
        "description": "Warm stable climate correlating with Roman and Han Dynasty peaks. Agricultural surplus supported population growth",
        "source": "McCormick et al. 2012"
    },
    {
        "event_id": 4,
        "event_name": "Late Antique Little Ice Age",
        "event_type": "climate",
        "start_year": 536,
        "end_year": 660,
        "severity": "severe",
        "geographic_scope": "global",
        "affected_regions": "Europe|Middle East|Central Asia|East Asia",
        "description": "Volcanic winters from 536 CE eruptions caused crop failures globally. Coincides with Justinianic Plague and multiple empire weakening",
        "source": "Büntgen et al. 2016; Keys 1999"
    },
    {
        "event_id": 5,
        "event_name": "Medieval Warm Period",
        "event_type": "climate",
        "start_year": 950,
        "end_year": 1250,
        "severity": "beneficial",
        "geographic_scope": "regional",
        "affected_regions": "Europe|Middle East",
        "description": "Warm period enabling agricultural expansion. Correlates with population growth in Europe and the Islamic Golden Age",
        "source": "Mann et al. 2009"
    },
    {
        "event_id": 6,
        "event_name": "Little Ice Age",
        "event_type": "climate",
        "start_year": 1300,
        "end_year": 1850,
        "severity": "moderate",
        "geographic_scope": "global",
        "affected_regions": "Europe|Middle East|East Asia|Americas",
        "description": "Extended cooling causing crop failures and famines across multiple continents. Contributed to 17th century general crisis",
        "source": "Parker 2013; Fagan 2000"
    },
    {
        "event_id": 7,
        "event_name": "Year Without a Summer",
        "event_type": "climate",
        "start_year": 1815,
        "end_year": 1817,
        "severity": "severe",
        "geographic_scope": "global",
        "affected_regions": "Europe|Americas|East Asia",
        "description": "Mount Tambora eruption 1815 caused global cooling. Crop failures across Europe and North America. Context for post-Napoleonic instability",
        "source": "Oppenheimer 2003"
    },

    # Pandemics
    {
        "event_id": 8,
        "event_name": "Antonine Plague",
        "event_type": "pandemic",
        "start_year": 165,
        "end_year": 180,
        "severity": "severe",
        "geographic_scope": "regional",
        "affected_regions": "Europe|Middle East",
        "description": "Smallpox or measles pandemic killing 5-10M in Roman Empire. Marked beginning of Roman demographic decline",
        "source": "Duncan-Jones 1996"
    },
    {
        "event_id": 9,
        "event_name": "Plague of Cyprian",
        "event_type": "pandemic",
        "start_year": 249,
        "end_year": 262,
        "severity": "severe",
        "geographic_scope": "regional",
        "affected_regions": "Europe|Middle East|North Africa",
        "description": "Unknown pathogen killing 5000/day at peak in Rome. Contributed to Crisis of the Third Century",
        "source": "Harper 2017"
    },
    {
        "event_id": 10,
        "event_name": "Justinianic Plague",
        "event_type": "pandemic",
        "start_year": 541,
        "end_year": 750,
        "severity": "catastrophic",
        "geographic_scope": "global",
        "affected_regions": "Europe|Middle East|North Africa|Central Asia",
        "description": "First major bubonic plague pandemic. Killed 25-50M. Devastated Byzantine and Sassanid empires simultaneously",
        "source": "Little 2007; Harbeck et al. 2013"
    },
    {
        "event_id": 11,
        "event_name": "Black Death",
        "event_type": "pandemic",
        "start_year": 1347,
        "end_year": 1353,
        "severity": "catastrophic",
        "geographic_scope": "global",
        "affected_regions": "Europe|Middle East|Central Asia|East Asia|North Africa",
        "description": "Bubonic plague killed 30-60% of European population and devastated Middle East and Central Asia. Travelled Mongol trade routes",
        "source": "Benedictow 2004"
    },
    {
        "event_id": 12,
        "event_name": "Columbian Exchange Pandemics",
        "event_type": "pandemic",
        "start_year": 1492,
        "end_year": 1600,
        "severity": "catastrophic",
        "geographic_scope": "regional",
        "affected_regions": "Americas",
        "description": "Smallpox, measles, influenza killed 50-90% of indigenous American populations. Directly enabled Spanish conquest of Aztec and Inca",
        "source": "Crosby 1972; Koch et al. 2019"
    },
    {
        "event_id": 13,
        "event_name": "Spanish Flu",
        "event_type": "pandemic",
        "start_year": 1918,
        "end_year": 1920,
        "severity": "catastrophic",
        "geographic_scope": "global",
        "affected_regions": "Europe|Americas|Asia|Africa",
        "description": "50-100M deaths globally. Struck at end of WWI contributing to political instability and empire collapses",
        "source": "Johnson & Mueller 2002"
    },

    # Mass Migration / Invasion Waves
    {
        "event_id": 14,
        "event_name": "Sea Peoples Migrations",
        "event_type": "migration",
        "start_year": -1200,
        "end_year": -1150,
        "severity": "severe",
        "geographic_scope": "regional",
        "affected_regions": "Middle East|Mediterranean|North Africa",
        "description": "Mass migrations and raids destroyed Hittites, Ugarit, Mycenae. Egypt survived barely. Core event of Bronze Age Collapse",
        "source": "Cline 2014"
    },
    {
        "event_id": 15,
        "event_name": "Hun Migrations into Europe",
        "event_type": "migration",
        "start_year": 370,
        "end_year": 450,
        "severity": "severe",
        "geographic_scope": "regional",
        "affected_regions": "Europe|Central Asia",
        "description": "Hun westward push displaced Germanic tribes into Roman territory. Directly contributed to Western Roman collapse",
        "source": "Heather 2006"
    },
    {
        "event_id": 16,
        "event_name": "Mongol Conquests",
        "event_type": "migration",
        "start_year": 1206,
        "end_year": 1279,
        "severity": "catastrophic",
        "geographic_scope": "global",
        "affected_regions": "Central Asia|Middle East|East Asia|Eastern Europe",
        "description": "Largest land empire conquest in history. Destroyed Abbasid Caliphate, Jin Dynasty, Song Dynasty, Kievan Rus",
        "source": "Morgan 1986"
    },

    # Major Wars and Geopolitical Shocks
    {
        "event_id": 17,
        "event_name": "Bronze Age Collapse",
        "event_type": "systemic_collapse",
        "start_year": -1200,
        "end_year": -1150,
        "severity": "catastrophic",
        "geographic_scope": "regional",
        "affected_regions": "Middle East|Mediterranean|North Africa",
        "description": "Simultaneous collapse of nearly every major Bronze Age civilisation. Multi-causal: drought, migration, trade disruption, internal revolt",
        "source": "Cline 2014"
    },
    {
        "event_id": 18,
        "event_name": "Thirty Years War",
        "event_type": "war",
        "start_year": 1618,
        "end_year": 1648,
        "severity": "severe",
        "geographic_scope": "regional",
        "affected_regions": "Europe",
        "description": "Devastated Central Europe. Holy Roman Empire lost up to 8M people. Began HRE terminal decline",
        "source": "Wilson 2009"
    },
    {
        "event_id": 19,
        "event_name": "World War I",
        "event_type": "war",
        "start_year": 1914,
        "end_year": 1918,
        "severity": "catastrophic",
        "geographic_scope": "global",
        "affected_regions": "Europe|Middle East|Africa|Asia",
        "description": "17-20M dead. Destroyed Ottoman, Austro-Hungarian, Russian, and German Empires simultaneously. Most destructive collapse cluster in modern history",
        "source": "MacMillan 2013"
    },
    {
        "event_id": 20,
        "event_name": "World War II",
        "event_type": "war",
        "start_year": 1939,
        "end_year": 1945,
        "severity": "catastrophic",
        "geographic_scope": "global",
        "affected_regions": "Europe|Asia|Africa|Americas",
        "description": "70-85M dead. Destroyed German, Italian, Japanese empires. Fatally weakened British and French colonial empires",
        "source": "Overy 2013"
    },
]

df_stressors = pd.DataFrame(stressor_events)
df_stressors.to_csv("../data/raw/external_stressors.csv", index=False)

print(f"Stressor events saved: {len(df_stressors)} events")
print(f"\nEvent types:")
print(df_stressors['event_type'].value_counts())
print(f"\nSeverity breakdown:")
print(df_stressors['severity'].value_counts())
print(f"\nYear range: {df_stressors['start_year'].min()} to {df_stressors['end_year'].max()}")
# Out:
# Stressor events saved: 20 events
#
# Event types:
# event_type
# climate              7
# pandemic             6
# migration            3
# war                  3
# systemic_collapse    1
# Name: count, dtype: int64
#
# Severity breakdown:
# severity
# severe          9
# catastrophic    8
# beneficial      2
# moderate        1
# Name: count, dtype: int64
#
# Year range: -2200 to 1945

# %%
import os

files = [
    "../data/raw/civilisations_master.csv",
    "../data/raw/external_stressors.csv",
]

for f in files:
    if os.path.exists(f):
        size = os.path.getsize(f) / 1024
        print(f"✓ {f} ({size:.1f} KB)")
    else:
        print(f"✗ MISSING: {f}")
# Out:
# ✓ ../data/raw/civilisations_master.csv (11.1 KB)
# ✓ ../data/raw/external_stressors.csv (4.6 KB)
